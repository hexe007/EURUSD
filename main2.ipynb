# %% [markdown]
# <a href="https://colab.research.google.com/github/hexe007/EURUSD/blob/main/main2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Indented block
# #This is set of instructions and excpectetion of forex trading algoryth

# %% [markdown]
# 1.Load dataset consisting of Date, Open, Close, High, Low, Volume going back 10 years
#
# 2.Eliminate gaps and nulls. Gap = price open 0.0001 >< price close
#
#
# 3.Graphical display of price change and colleration between O,C,H,L - open,close,high,low
#
# 4.Presetting economic instruments:moving averages, stochastic, MACD, RSI
#
# 5.Tokenazing dataset

# %%
#import necessary libraries/modules
# !pip install mplfinance

import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 1.8 MB/s eta 0:00:00
# ...

# %%
df = pd.read_csv('/content/eurusd60.csv')

# Combine 'Date' and 'Time' columns into a single column
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])

# Set 'DateTime' column as the index
df.set_index('DateTime', inplace=True)

# Drop the 'Date' and 'Time' columns if no longer needed
df.drop(['Date', 'Time'], axis=1, inplace=True)

# %%
sample_interval = 10
samples = df.iloc[100:150]

samples_open = df['Open'][100:150]
samples_high = df['High'][100:150]
samples_low = df['Low'][100:150]
samples_close = df['Close'][100:150]

# %%
mpf.plot(samples, type='candle')

# %%
# Create a figure and subplots
fig, ax = plt.subplots()

# Plot the first graph
ax.plot(samples_open, samples_high, label='Graph 1')

# Plot the second graph
ax.plot(samples_open, samples_low, label='Graph 2')

# Plot the third graph
ax.plot(samples_open, samples_close, label='Graph 3')

# Add a legend
ax.legend()

# Display the plot
print(x)
